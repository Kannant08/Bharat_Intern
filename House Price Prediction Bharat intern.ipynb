# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('C:/Users/THIRU/Documents/DATA SET/House Price India.csv')

# %%
df.head(10)
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
# 5  6762813105  42491                   3                 2.50         2600
# 6  6762813157  42491                   5                 3.25         3660
# 7  6762813599  42491                   3                 1.75         2240
# 8  6762813600  42491                   3                 2.50         2390
# 9  6762814461  42491                   4                 2.25         2200
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# ...

# %%
df.describe().transpose()
# Out:
#                                          count          mean            std  \
# id                                     14620.0  6.762821e+09    6237.574799
# Date                                   14620.0  4.260454e+04      67.347991
# number of bedrooms                     14620.0  3.379343e+00       0.938719
# number of bathrooms                    14620.0  2.129583e+00       0.769934
# living area                            14620.0  2.098263e+03     928.275721
# lot area                               14620.0  1.509328e+04   37919.621304
# number of floors                       14620.0  1.502360e+00       0.540239
# waterfront present                     14620.0  7.660739e-03       0.087193
# number of views                        14620.0  2.331053e-01       0.766259
# condition of the house                 14620.0  3.430506e+00       0.664151
# grade of the house                     14620.0  7.682421e+00       1.175033
# ...

# %%
df.isnull().any()
# Out:
# id                                       False
# Date                                     False
# number of bedrooms                       False
# number of bathrooms                      False
# living area                              False
# lot area                                 False
# number of floors                         False
# waterfront present                       False
# number of views                          False
# condition of the house                   False
# grade of the house                       False
# Area of the house(excluding basement)    False
# Area of the basement                     False
# Built Year                               False
# Renovation Year                          False
# Postal Code                              False
# Lattitude                                False
# Longitude                                False
# living_area_renov                        False
# lot_area_renov                           False
# ...

# %%
df.shape
# Out:
# (14620, 23)

# %%
plt.figure(figsize=(10,6))
sns.distplot(df['Price'])
# Out:
# C:\Users\THIRU\AppData\Local\Temp\ipykernel_7608\1398071620.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.countplot(x=df['number of bedrooms'])
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='number of bedrooms',y='Price',data=df)
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='Price'>

# %%
len(df)*0.01
# Out:
# 146.20000000000002

# %%
#Removing the top 1 percent for better visualization

# %%
non_top_1perc=df.sort_values('Price',ascending=False).iloc[146:]

# %%
non_top_1perc.head()
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 5684   6762810242  42575                   4                 3.50
# 14533  6762810244  42733                   4                 4.00
# 13490  6762810254  42708                   3                 4.50
# 9865   6762810253  42643                   4                 3.25
# 3870   6762810252  42550                   5                 4.25
#
#        living area  lot area  number of floors  waterfront present  \
# 5684          4065     18713               2.0                   0
# 14533         4690      6900               2.0                   0
# 13490         3950      6134               2.0                   0
# 9865          4280     20296               2.0                   0
# 3870          4830      8050               2.5                   0
#
#        number of views  condition of the house  ...  Built Year  \
# 5684                 0                       4  ...        1987
# ...

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Longitude',y='Lattitude',data=non_top_1perc,hue='Price',edgecolor=None,alpha=0.2,palette='RdYlGn')
# Out:
# <Axes: xlabel='Longitude', ylabel='Lattitude'>

# %%
sns.boxplot(x='waterfront present',y='Price',data=df)
# Out:
# <Axes: xlabel='waterfront present', ylabel='Price'>

# %%
df=df.drop(columns='id',axis=1)

# %%
df
# Out:
#         Date  number of bedrooms  number of bathrooms  living area  lot area  \
# 0      42491                   5                 2.50         3650      9050
# 1      42491                   4                 2.50         2920      4000
# 2      42491                   5                 2.75         2910      9480
# 3      42491                   4                 2.50         3310     42998
# 4      42491                   3                 2.00         2710      4500
# ...      ...                 ...                  ...          ...       ...
# 14615  42734                   2                 1.50         1556     20000
# 14616  42734                   3                 2.00         1680      7000
# 14617  42734                   2                 1.00         1070      6120
# 14618  42734                   4                 1.00         1030      6621
# 14619  42734                   3                 1.00          900      4770
#
# ...

# %%
df['Date']
# Out:
# 0        42491
# 1        42491
# 2        42491
# 3        42491
# 4        42491
#          ...
# 14615    42734
# 14616    42734
# 14617    42734
# 14618    42734
# 14619    42734
# Name: Date, Length: 14620, dtype: int64

# %%
#Transforming the date column to datetime format

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Date']
# Out:
# 0       1970-01-01 00:00:00.000042491
# 1       1970-01-01 00:00:00.000042491
# 2       1970-01-01 00:00:00.000042491
# 3       1970-01-01 00:00:00.000042491
# 4       1970-01-01 00:00:00.000042491
#                      ...
# 14615   1970-01-01 00:00:00.000042734
# 14616   1970-01-01 00:00:00.000042734
# 14617   1970-01-01 00:00:00.000042734
# 14618   1970-01-01 00:00:00.000042734
# 14619   1970-01-01 00:00:00.000042734
# Name: Date, Length: 14620, dtype: datetime64[ns]

# %%
df['Year']=df['Date'].apply(lambda Date: Date.year)

# %%
df['Month']=df['Date'].apply(lambda Date: Date.month)

# %%
df=df.drop(columns='Date',axis=1)

# %%
df.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                 2.50         3650      9050
# 1                   4                 2.50         2920      4000
# 2                   5                 2.75         2910      9480
# 3                   4                 2.50         3310     42998
# 4                   3                 2.00         2710      4500
#
#    number of floors  waterfront present  number of views  \
# 0               2.0                   0                4
# 1               1.5                   0                0
# 2               1.5                   0                0
# 3               2.0                   0                0
# 4               1.5                   0                0
#
#    condition of the house  grade of the house  \
# 0                       5                  10
# 1                       5                   8
# 2                       3                   8
# ...

# %%
df=df.drop(columns='Postal Code',axis=1)

# %%
df.head()
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                 2.50         3650      9050
# 1                   4                 2.50         2920      4000
# 2                   5                 2.75         2910      9480
# 3                   4                 2.50         3310     42998
# 4                   3                 2.00         2710      4500
#
#    number of floors  waterfront present  number of views  \
# 0               2.0                   0                4
# 1               1.5                   0                0
# 2               1.5                   0                0
# 3               2.0                   0                0
# 4               1.5                   0                0
#
#    condition of the house  grade of the house  \
# 0                       5                  10
# 1                       5                   8
# 2                       3                   8
# ...

# %%
x=df.drop(columns='Price',axis=1)
y=df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
X_train.shape,X_test.shape
# Out:
# ((9795, 21), (4825, 21))

# %%
y_train.shape,y_test.shape
# Out:
# ((9795,), (4825,))

# %%
#Scaling the data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=lm.predict(X_test)

# %%
from sklearn import metrics

# %%
#Ploting predictions vs actual values

# %%
plt.figure(figsize=(10,5))
plt.scatter(y_test,predictions)
plt.xlabel('y test(True Values)')
plt.ylabel('predictions')
plt.plot(y_test,y_test,'r')

# %%
metrics.explained_variance_score(y_test,predictions)
# Out:
# 0.7077865339375526

# %%
# Giving the model a sample data and predicting the Price value

# %%
single_house=pd.DataFrame(df.iloc[0]).transpose()

# %%
single_house
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                 5.0                  2.5       3650.0    9050.0
#
#    number of floors  waterfront present  number of views  \
# 0               2.0                 0.0              4.0
#
#    condition of the house  grade of the house  \
# 0                     5.0                10.0
#
#    Area of the house(excluding basement)  ...  Renovation Year  Lattitude  \
# 0                                 3370.0  ...              0.0    52.8645
#
#    Longitude  living_area_renov  lot_area_renov  Number of schools nearby  \
# 0   -114.557             2880.0          5400.0                       2.0
#
#    Distance from the airport      Price    Year  Month
# 0                       58.0  2380000.0  1970.0    1.0
#
# [1 rows x 22 columns]

# %%
s1=single_house.drop(columns='Price',axis=1)
s1
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                 5.0                  2.5       3650.0    9050.0
#
#    number of floors  waterfront present  number of views  \
# 0               2.0                 0.0              4.0
#
#    condition of the house  grade of the house  \
# 0                     5.0                10.0
#
#    Area of the house(excluding basement)  ...  Built Year  Renovation Year  \
# 0                                 3370.0  ...      1921.0              0.0
#
#    Lattitude  Longitude  living_area_renov  lot_area_renov  \
# 0    52.8645   -114.557             2880.0          5400.0
#
#    Number of schools nearby  Distance from the airport    Year  Month
# 0                       2.0                       58.0  1970.0    1.0
#
# [1 rows x 21 columns]

# %%
s1=scaler.transform(s1)

# %%
sample_prediction=lm.predict(s1)

# %%
print(sample_prediction)
# Out:
# [1429584.1712295]
